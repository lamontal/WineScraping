# %%
from IPython.display import Image

# %%
Image("WineSummary.png")

# %%
Image("Regional_rating.png")

# %%
Image("ML_Data.png")

# %%
import pandas as pd
df= pd.read_csv("all3_ML_AvgPrecp.csv")
df
# Out:
#     Unnamed: 0     Rating     PRCP 1     TAVG 1     PRCP 2     TAVG 2  \
# 0         1996  89.000000   8.960000  49.100000   8.260000  53.600000
# 1         1997  87.900000  10.350000  48.800000   0.650000  52.700000
# 2         1998  87.666667  12.000000  50.100000  18.900000  50.200000
# 3         1999  87.258065   4.210000  46.400000  11.330000  49.100000
# 4         2000  87.888889   5.710000  50.000000  10.810000  52.000000
# 5         2001  87.972222   3.370000  45.800000   4.740000  49.300000
# 6         2002  86.671429   3.980000  46.700000   2.530000  52.000000
# 7         2003  87.055556   3.000000        NaN   2.290000  50.800000
# 8         2004  86.980000   3.000000        NaN   6.310000  50.600000
# 9         2005  87.432836   4.190000  46.300000   4.360000  52.600000
# 10        2006  87.376623   3.880000  49.100000   4.110000  50.600000
# 11        2007  88.389610   0.470000  45.100000   5.930000  49.600000
# ...
